# %% [markdown]
# <a href="https://colab.research.google.com/github/MohitPolisetty/DS-Experiments-TY-CSE-AI-DS/blob/main/Experiment5DS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


df = pd.read_csv('mtcars.csv')

# %% [markdown]
# Line charts

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x=df['gear'], y=df['hp'], data=df, marker='o', label='Line with Markers', color='blue')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line Chart')
plt.legend()

plt.show()

# %% [markdown]
# Count Plot

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x=df['mpg'], data=df, palette='viridis')
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('Count Plot')

plt.show()
# Out:
# <ipython-input-6-bbb73425574b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['mpg'], data=df, palette='viridis')
